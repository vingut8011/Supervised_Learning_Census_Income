# %% [markdown]
# Supervised Learning on Census Income - 2026-05-30 - vingut8011

# %%
data.head()
data.info()
data.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.head()
#       2 data.info()
#       3 data.describe()
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# %%
import pandas as pd

data = pd.read_csv('census_income_dataset.csv')

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nFiles in Folder:")
print(os.listdir())

# %%
import pandas as pd

data = pd.read_csv('PA_Census_IncomeData.csv')

# %%
import pandas as pd

# %%
data = pd.read_csv('PA_Census_IncomeData.csv')

# %%
import os

for root, dirs, files in os.walk(r"C:\Users\iaasi"):
    for file in files:
        if "census" in file.lower() or "income" in file.lower():
            print(os.path.join(root, file))

# %%
import pandas as pd

data = pd.read_csv(
    r'C:\Users\iaasi\Documents\SDC485DocumentsECPI_AI_Class\census_income_dataset.csv'
)

print("Dataset Loaded Successfully!")

# %% [markdown]
# from IPython.display import display, Markdown
#
# display(Markdown("## Load and Explore Dataset"))
# display(Markdown("**Date:** 2026-05-30"))
# display(Markdown("**Student ID:** vingut8011"))
#
# data.head()

# %%
from IPython.display import display, Markdown

display(Markdown("## Load and Explore Dataset"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

data.head()

# %%
display(Markdown("## Load and Explore Dataset"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

data.head()

# %%
display(Markdown("## Preprocessing Data"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

print("Missing Values:")
print(data.isnull().sum())

# %%
print("Duplicate Rows Before:", data.duplicated().sum())

data = data.drop_duplicates()

print("Duplicate Rows After:", data.duplicated().sum())

# %%
data['income'] = data['income'].apply(
    lambda x: 1 if str(x).strip() == '>50K' else 0
)

print(data['income'].value_counts())

# %%
data = pd.get_dummies(data, drop_first=True)

print("Dataset Shape After Encoding:")
print(data.shape)

# %%
from sklearn.model_selection import train_test_split

X = data.drop('income', axis=1)
y = data['income']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)

# %%
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Implement K-Nearest Neighbors Algorithm"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

knn = KNeighborsClassifier()

knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

print("KNN model trained successfully.")
print("First 10 predictions:")
print(y_pred[:10])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

display(Markdown("## Evaluate the Model"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)

print("\nConfusion Matrix:")
print(cm)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
from IPython.display import display, Markdown
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

# %%
param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Faster version
X_train_small = X_train.sample(10000, random_state=42)
y_train_small = y_train.loc[X_train_small.index]

grid.fit(X_train_small, y_train_small)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
from sklearn.model_selection import train_test_split

X = data.drop('income', axis=1)
y = data['income']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)

# %%
from sklearn.model_selection import train_test_split

X = data.drop('income', axis=1)
y = data['income']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
from sklearn.model_selection import train_test_split

X = data.drop('income', axis=1)
y = data['income']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)

# %%
print(type(data))
print(data.shape)

# %%
import pandas as pd

data = pd.read_csv(
    r'C:\Users\iaasi\Documents\SDC485DocumentsECPI_AI_Class\census_income_dataset.csv'
)

print("Dataset Loaded Successfully!")

# %%
data['income'] = data['income'].apply(
    lambda x: 1 if str(x).strip() == '>50K' else 0
)

data = pd.get_dummies(data, drop_first=True)

print(data.shape)

# %%
from sklearn.model_selection import train_test_split

X = data.drop('income', axis=1)
y = data['income']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
from IPython.display import display, Markdown

# %%
from IPython.display import display, Markdown
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
from sklearn.model_selection import train_test_split

X = data.drop('income', axis=1)
y = data['income']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)

# %%
from sklearn.model_selection import train_test_split

X = data.drop('income', axis=1)
y = data['income']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)

# %%
from IPython.display import display, Markdown
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)
X_train_small = X_train.sample(10000, random_state=42)
y_train_small = y_train.loc[X_train_small.index]

grid.fit(X_train_small, y_train_small)


print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
from IPython.display import display, Markdown
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)
# Out:
# ## Apply GridSearchCV for Hyperparameter Tuning
# **Date:** 2026-05-30
# **Student ID:** vingut8011
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 23
#       9 param_grid = {
#      10     'n_neighbors': [3, 5, 7, 9],
#      11     'weights': ['uniform', 'distance'],
#      12     'metric': ['euclidean', 'manhattan', 'minkowski']
#      13 }
#      15 grid = GridSearchCV(
#      16     KNeighborsClassifier(),
#      17     param_grid,
#    (...)     20     n_jobs=-1
#      21 )
# ---> 23 grid.fit(X_train, y_train)
#      25 print("Best Parameters:", grid.best_params_)
#      26 print("Best Score:", grid.best_score_)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.model_selection import train_test_split

X = data.drop('income', axis=1)
y = data['income']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X = data.drop('income', axis=1)
#       4 y = data['income']
#       6 X_train, X_test, y_train, y_test = train_test_split(
#       7     X,
#       8     y,
#       9     test_size=0.30,
#      10     random_state=42
#      11 )
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

data = pd.read_csv(
    r'C:\Users\iaasi\Documents\SDC485DocumentsECPI_AI_Class\census_income_dataset.csv'
)

print("Dataset Loaded Successfully!")
print(data.shape)
# Out:
# Dataset Loaded Successfully!
# (48842, 15)

# %%
data['income'] = data['income'].apply(
    lambda x: 1 if str(x).strip() == '>50K' else 0
)

data = pd.get_dummies(data, drop_first=True)

print("Preprocessing complete")
print(data.shape)
# Out:
# Preprocessing complete
# (48842, 101)

# %%
from sklearn.model_selection import train_test_split

X = data.drop('income', axis=1)
y = data['income']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (34189, 100)
# Testing Shape: (14653, 100)

# %%
from IPython.display import display, Markdown
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
print("hello")

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
from IPython.display import display, Markdown

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

display(Markdown("## Apply GridSearchCV for Hyperparameter Tuning"))
display(Markdown("**Date:** 2026-05-30"))
display(Markdown("**Student ID:** vingut8011"))

# Load dataset
data = pd.read_csv(
    r'C:\Users\iaasi\Documents\SDC485DocumentsECPI_AI_Class\census_income_dataset.csv'
)

# Preprocess data
data = data.drop_duplicates()

data['income'] = data['income'].apply(
    lambda x: 1 if str(x).strip() == '>50K' else 0
)

data = pd.get_dummies(data, drop_first=True)

# Train/test split
X = data.drop('income', axis=1)
y = data['income']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)

# Smaller sample so GridSearchCV runs faster
X_train_small = X_train.sample(5000, random_state=42)
y_train_small = y_train.loc[X_train_small.index]

# GridSearchCV
param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train_small, y_train_small)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# Refit best model and evaluate
best_knn = grid.best_estimator_
best_knn.fit(X_train_small, y_train_small)

y_pred_tuned = best_knn.predict(X_test)

print("\nTuned Model Results")
print("Accuracy:", accuracy_score(y_test, y_pred_tuned))
print("Precision:", precision_score(y_test, y_pred_tuned))
print("Recall:", recall_score(y_test, y_pred_tuned))
print("F1 Score:", f1_score(y_test, y_pred_tuned))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_tuned))
# Out:
# ## Apply GridSearchCV for Hyperparameter Tuning
# **Date:** 2026-05-30
# **Student ID:** vingut8011
# Training Shape: (34169, 100)
# Testing Shape: (14644, 100)
# Best Parameters: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'uniform'}
# Best Score: 0.835
#
# Tuned Model Results
# Accuracy: 0.8376809614859329
# Precision: 0.5109780439121756
# Recall: 0.10720268006700168
# F1 Score: 0.17722395292488752
#
# Confusion Matrix:
# [[12011   245]
#  [ 2132   256]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, tuned_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues',
            xticklabels=['<=50K','>50K'],
            yticklabels=['<=50K','>50K'])

plt.title('Confusion Matrix Heatmap')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 import matplotlib.pyplot as plt
#       3 from sklearn.metrics import confusion_matrix
# ----> 5 cm = confusion_matrix(y_test, tuned_pred)
#       7 plt.figure(figsize=(6,4))
#       8 sns.heatmap(cm,
#       9             annot=True,
#      10             fmt='d',
#      11             cmap='Blues',
#      12             xticklabels=['<=50K','>50K'],
#      13             yticklabels=['<=50K','>50K'])
#
# NameError: name 'tuned_pred' is not defined

# %%
best_knn = grid.best_estimator_

tuned_pred = best_knn.predict(X_test)

print("Predictions created successfully!")
# Out:
# Predictions created successfully!

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, tuned_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues',
            xticklabels=['<=50K','>50K'],
            yticklabels=['<=50K','>50K'])

plt.title('Confusion Matrix Heatmap')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

y_prob = best_knn.predict_proba(X_test)[:,1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.3f}')
plt.plot([0,1],[0,1],'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

print("AUC Score:", roc_auc)
# Out:
# AUC Score: 0.6078789973584195
